# %%
def greet_and_introduce():
    """
    Выводит на экран приветствие, имя пользователя и дополнительную строку.
    
    Функция выполняет следующие действия:
    1. Печатает 'Hello World'
    2. Выводит 'My name is Ekaterina'
    3. Отображает заглушку/ошибку в виде строки 'jnkjkjk'
    
    Примечание: Третья строка может быть временной меткой или опечаткой.
    """
    print('Hello World')
    print('My name is Ekaterina')
    print('jnkjkjk')
# Out:
# Hello World
# My name is Ekaterina
# jnkjkjk

# %%
# Верхние лепестки
print("  *   *")
print(" *   *")
print("*   *")

# Центр цветка
print(" ***** ")

# Нижние лепестки
print("  * *")
print("*     *")
print("  * *")

# Стебель
print("  --  ")
print("  --  ")
print("  --  ")
# Out:
#   *   *
#  *   *
# *   *
#  *****
#   * *
# *     *
#   * *
#   --
#   --
#   --
